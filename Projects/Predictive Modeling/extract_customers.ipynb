# %%
import pandas as pd

# %%
rawData = pd.read_excel('./data/retail_data_synthetic_50k.xlsx')
print(rawData.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Transaction_ID     50000 non-null  object
#  1   Customer_ID        50000 non-null  object
#  2   Gender             50000 non-null  object
#  3   Age                50000 non-null  int64
#  4   Category           50000 non-null  object
#  5   Quantity           50000 non-null  int64
#  6   Unit_Price         50000 non-null  float64
#  7   Discount           50000 non-null  float64
#  8   Date               50000 non-null  datetime64[ns]
#  9   Store_Region       50000 non-null  object
#  10  Online_Or_Offline  50000 non-null  object
#  11  Payment_Method     50000 non-null  object
#  12  Total_Amount       50000 non-null  float64
# dtypes: datetime64[ns](1), float64(3), int64(2), object(7)
# memory usage: 5.0+ MB
# None

# %%
# byUser = rawData.groupby(['Customer_ID'])
print(rawData['Quantity'].unique())
print(rawData['Category'].unique())
print(rawData['Payment_Method'].unique())
print(rawData['Online_Or_Offline'].unique())
print()
print()
# Out:
# [9 4 1 7 2 3 8 6 5]
# ['Furniture' 'Beauty' 'Clothing' 'Electronics' 'Grocery']
# ['Digital Wallet' 'Cash' 'Credit Card']
# ['Online' 'In-store']

# %%
rawData['Year'] = rawData['Date'].dt.year
print(rawData['Year'].unique())
year_2020 = rawData[rawData['Year'] == 2020]
year_2021 = rawData[rawData['Year'] == 2021]
year_2022 = rawData[rawData['Year'] == 2022]
year_2023 = rawData[rawData['Year'] == 2023]
# Out:
# [2023 2021 2020 2022]

# %%
# Data for 2020
n20 = year_2020[year_2020['Store_Region'] == 'North']
s20 = year_2020[year_2020['Store_Region'] == 'South']
e20 = year_2020[year_2020['Store_Region'] == 'East']
w20 = year_2020[year_2020['Store_Region'] == 'West']

n20_online = n20[n20['Online_Or_Offline'] == 'Online']
n20_store = n20[n20['Online_Or_Offline'] == 'In-store']

# print(n20_online['Customer_ID'].unique())
# print(n20_online[n20_online['Customer_ID'] == 'CUST-0021'])
# print(n20_store[n20_store['Customer_ID'] == 'CUST-0021'])

# print(n20[n20['Customer_ID'] == 'CUST-0088'])
# print(year_2020[year_2020['Customer_ID'] == 'CUST-0861'])

# %%
region_north = rawData[rawData['Store_Region'] == 'North']
online_transactions = region_north[region_north['Online_Or_Offline'] == 'Online']
offline_transactions = region_north[region_north['Online_Or_Offline'] == 'In-store']
# sampleUser = online_transactions[online_transactions['Customer_ID'] == 'CUST-1127'] CUST-0088
sampleUser = offline_transactions[offline_transactions['Customer_ID'] == 'CUST-0088'] 
print(sampleUser)
# Out:
#       Transaction_ID Customer_ID  Gender  Age     Category  Quantity  \
# 14         TXN-00014   CUST-0088    Male   22     Clothing         1
# 43962      TXN-43962   CUST-0088  Female   35  Electronics         7
#
#        Unit_Price  Discount       Date Store_Region Online_Or_Offline  \
# 14         304.32      0.16 2020-06-23        North          In-store
# 43962      321.80      0.30 2023-12-10        North          In-store
#
#        Payment_Method  Total_Amount
# 14               Cash        255.63
# 43962  Digital Wallet       1576.82

# %%
# userColumns=['Customer_ID', 'Gender', 'Age', 'Region_North_Count',
#              'Region_West_Count', 'Region_South_Count', 'Region_East_Count',
#              'Online_Count', 'Offline_Count', 'Payment_Wallet_Count',
#              'Payment_Cash_Count', 'Payment_CC_Count', 'Transaction_Count',
#              'Total_Spend','Mean_Spend','Category_Furnature_Count',
#              'Category_Beauty_Count','Category_Clothing_Count','Category_Electronics_Count',
#              'Category_Grocery_Count']
# customerFrame = pd.DataFrame(columns=userColumns)
# byUser = rawData.groupby(by='Customer_ID')
# print(byUser['Customer_ID'].head())
# customerFrame['Customer_ID'] = byUser.groups.keys()
# customerFrame['Gender'] = byUser['Gender']
# for user in rawData.groupby('Customer_ID'):
#     print(user)
# for user_id in rawData['Customer_ID'].unique():
#     newCustomer = pd.DataFrame({
#         'Customer_ID': user_id,
#         'Gender': rawData[rawData['Customer_ID'] == user_id]['Gender'],
#         'Age': rawData[rawData['Customer_ID'] == user_id]['Age'],
        # 'Region_North_Count': rawData[rawData['Customer_ID'] == user_id and rawData['Store_Region'] == 'North'].count(),
        # 'Region_West_Count': rawData[rawData['Customer_ID'] == user_id and rawData['Store_Region'] == 'West'].count(),
        # 'Region_South_Count': rawData[rawData['Customer_ID'] == user_id and rawData['Store_Region'] == 'South'].count(),
        # 'Region_East_Count': rawData[rawData['Customer_ID'] == user_id and rawData['Store_Region'] == 'East'].count(),
        # 'Online_Count': rawData[rawData['Customer_ID'] == user_id and rawData['Online_or_Offline'] == 'Online'].count(),
        # 'Offline_Count': rawData[rawData['Customer_ID'] == user_id and rawData['Online_or_Offline'] == 'Offline'].count(),
        # 'Payment_Wallet_Count': rawData[rawData['Customer_ID'] == user_id and rawData['Payment_Method'] == 'Digital Wallet'].count(),
        # 'Payment_Cash_Count': rawData[rawData['Customer_ID'] == user_id and rawData['Payment_Method'] == 'Cash'].count(),
        # 'Payment_CC_Count': rawData[rawData['Customer_ID'] == user_id and rawData['Payment_Method'] == 'Credit Card'].count(),
        # 'Transaction_Count': rawData[rawData['Customer_ID'] == user_id].count(),
        # 'Total_Spend': rawData[rawData['Customer_ID'] == user_id]['Total_Amount'].sum(),
        # 'Mean_Spend': rawData[rawData['Customer_ID'] == user_id]['Total_Amount'].mean(),
        # 'Category_Furnature_Count': rawData[rawData['Customer_ID'] == user_id and rawData['Category'] == 'Furniture'],
        # 'Category_Beauty_Count': rawData[rawData['Customer_ID'] == user_id and rawData['Category'] == 'Beauty'],
        # 'Category_Clothing_Count': rawData[rawData['Customer_ID'] == user_id and rawData['Category'] == 'Clothing'],
        # 'Category_Electronics_Count': rawData[rawData['Customer_ID'] == user_id and rawData['Category'] == 'Electronics'],
        # 'Category_Grocery_Count': rawData[rawData['Customer_ID'] == user_id and rawData['Category'] == 'Grocery']
    # })
    # customerFrame = pd.concat([customerFrame, newCustomer])

# print(len(customerFrame))
# Out:
# 0        CUST-1127
# 1        CUST-1460
# 2        CUST-0861
# 3        CUST-1295
# 4        CUST-1131
#            ...
# 28674    CUST-0252
# 28840    CUST-0829
# 29421    CUST-1454
# 31886    CUST-0094
# 33692    CUST-0094
# Name: Customer_ID, Length: 9995, dtype: object
