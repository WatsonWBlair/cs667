# %%
import pandas as pd

# %%
cleanData = pd.read_csv('./data/clean_data.csv')

# %%
engData = cleanData.copy()

print(engData.head().to_markdown())
# Out:
# |    | Timestamp           |   TransactionID |   AccountID |   Amount | Merchant   | TransactionType   | Location    |
# |---:|:--------------------|----------------:|------------:|---------:|:-----------|:------------------|:------------|
# |  0 | 2023-01-01 08:00:00 |            1127 |           4 | 95071.9  | H          | Purchase          | Tokyo       |
# |  1 | 2023-01-01 08:01:00 |            1639 |          10 | 15607.9  | H          | Purchase          | London      |
# |  2 | 2023-01-01 08:02:00 |             872 |           8 | 65092.3  | E          | Withdrawal        | London      |
# |  3 | 2023-01-01 08:03:00 |            1438 |           6 |    87.87 | E          | Purchase          | London      |
# |  4 | 2023-01-01 08:04:00 |            1338 |           6 |   716.56 | I          | Purchase          | Los Angeles |

# %%
# Add Time Destruction
engData['Timestamp'] = pd.to_datetime(engData['Timestamp'])

engData['Year'] = engData['Timestamp'].dt.year
engData['Quarter'] = engData['Timestamp'].dt.quarter
engData['Month'] = engData['Timestamp'].dt.month

engData['Day_Of_Week'] = engData['Timestamp'].dt.day_name()
engData['Day_Of_Month'] = engData['Timestamp'].dt.day
engData['Day_Of_Year'] = engData['Timestamp'].dt.day_of_year

engData['Hour'] = engData['Timestamp'].dt.hour
engData['Minute'] = engData['Timestamp'].dt.minute

print(engData.head().to_markdown())
# Out:
# |    | Timestamp           |   TransactionID |   AccountID |   Amount | Merchant   | TransactionType   | Location    |   Year |   Quarter |   Month | Day_Of_Week   |   Day_Of_Month |   Day_Of_Year |   Hour |   Minute |
# |---:|:--------------------|----------------:|------------:|---------:|:-----------|:------------------|:------------|-------:|----------:|--------:|:--------------|---------------:|--------------:|-------:|---------:|
# |  0 | 2023-01-01 08:00:00 |            1127 |           4 | 95071.9  | H          | Purchase          | Tokyo       |   2023 |         1 |       1 | Sunday        |              1 |             1 |      8 |        0 |
# |  1 | 2023-01-01 08:01:00 |            1639 |          10 | 15607.9  | H          | Purchase          | London      |   2023 |         1 |       1 | Sunday        |              1 |             1 |      8 |        1 |
# |  2 | 2023-01-01 08:02:00 |             872 |           8 | 65092.3  | E          | Withdrawal        | London      |   2023 |         1 |       1 | Sunday        |              1 |             1 |      8 |        2 |
# |  3 | 2023-01-01 08:03:00 |            1438 |           6 |    87.87 | E          | Purchase          | London      |   2023 |         1 |       1 | Sunday        |              1 |             1 |      8 |        3 |
# |  4 | 2023-01-01 08:04:00 |            1338 |           6 |   716.56 | I          | Purchase          | Los Angeles |   2023 |         1 |       1 | Sunday        |              1 |             1 |      8 |        4 |

# %%
engData.to_csv('./data/eng_data.csv', index=False)
